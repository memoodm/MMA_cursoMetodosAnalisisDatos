# %% [markdown]
# <h1 style="color: red; text-align: center;"> Tarea 3 </h1>
# <h3 style="color: red; text-align: center;"> Por: Guillermo De Mendoza </h3>
# <h3 style="color: red; text-align: center;"> Materia: Mineria de datos </h3>

# %% [markdown]
# ### Importar librerias

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import seaborn as sns

# %% [markdown]
# ### Obtener el set de datos

# %%
df_all_countries = pd.read_csv('.\\resources\\MixedCountriesCrunchBase.csv')
df_top_100_colombia = pd.read_excel('.\\resources\\Top100Startups-Colombia.xlsx')

# %% [markdown]
# ### Visualizar datos MixedCountriesCrunchBase.csv

# %%
#preview data
df_all_countries.head(1)
# Out:
#   Organization Name                            Organization Name URL  \
# 0           La Haus  https://www.crunchbase.com/organization/la-haus
#
#                                           Industries  \
# 0  Information Technology, Marketplace, Real Esta...
#
#            Headquarters Location  \
# 0  Medellín, Antioquia, Colombia
#
#                                          Description CB Rank (Company)  \
# 0  La Haus is a residential marketplace used to h...             1,457
#
#   Headquarters Regions Estimated Revenue Range Operating Status Founded Date  \
# 0        Latin America             $1M to $10M           Active   2017-04-01
#
#    ... IPqwery - Trademarks Registered IPqwery - Most Popular Patent Class  \
# 0  ...                             NaN                                 NaN
#
#   IPqwery - Most Popular Trademark Class Aberdeen - IT Spend  \
# 0                                    NaN                 NaN
#
# ...

# %%
#data shape
print("Filas: %d"%(df_all_countries.shape[1]))
print("Columnas: %d"%(df_all_countries.shape[0]))
# Out:
# Filas: 106
# Columnas: 6647

# %% [markdown]
# ### Visualizar datos Top100Startups-Colombia.xlsx

# %%
#preview data
df_top_100_colombia
# Out:
#      INDEX       NAME                  EMAIL
# 0        1      1Doc3     jcardona@1doc3.com
# 1        2       ADDI       ssuarez@addi.com
# 2        3     Aflore       manuel@aflore.co
# 3        4     Agrapp        david@agrapp.co
# 4        5     Aptuno   alejandro@aptuno.com
# ..     ...        ...                    ...
# 106    107  Monolegal                    NaN
# 107    108  Finsocial  santiago@finsocial.co
# 108    109        NaN                    NaN
# 109    110        NaN                    NaN
# 110    111        NaN                    NaN
#
# [111 rows x 3 columns]

# %%
#data shape
print("Filas: %d"%(df_top_100_colombia.shape[1]))
print("Columnas: %d"%(df_top_100_colombia.shape[0]))
# Out:
# Filas: 3
# Columnas: 111

# %% [markdown]
# ### Operar el top 100 de empresas colombianas en MixedCountriesCrunchBase.csv

# %%
startup_contained = []
startup_not_contained = []

df_colombia_company = df_all_countries[ df_all_countries['Country'] == 'Colombia' ]
list_colombia_company_names = df_colombia_company['Organization Name'].tolist()

for i in range(100):
    top_company_name = df_top_100_colombia.iloc[i].NAME
    if top_company_name.upper() in (top_company_name.upper() for top_company_name in list_colombia_company_names):
        startup_contained.append(top_company_name)
    else:
        startup_not_contained.append(top_company_name)

print("[%d] estan contenidas, [%d] no estan contenidas"%(len(startup_contained),len(startup_not_contained)))
# Out:
# [34] estan contenidas, [66] no estan contenidas

# %%
# SI estan contenidas en el archivo MixedCountriesCrunchBase
startup_contained
# Out:
# ['ADDI',
#  'Aflore',
#  'Aptuno',
#  'Avista',
#  'Biocredit',
#  'Chiper',
#  'DataWifi',
#  'Farmalisto',
#  'Finaktiva',
#  'Fitpal',
#  'Fluvip',
#  'Foody',
#  'Frubana',
#  'Habi',
#  'Hometuls',
#  'La Haus',
#  'Laika',
#  'Leal',
#  'Lentesplus',
#  'Licify',
#  'Liftit',
#  'Mi Aguila',
#  'Minka',
#  'Muvo',
#  'Peiky',
#  'Queo',
#  'Rappi',
#  'Saludtools',
#  'Sempli',
#  'Simetrik',
#  'Truora',
#  'Valienta',
#  'Valiu',
#  'Zinobe']

# %%
# NO estan contenidas en el archivo MixedCountriesCrunchBase
startup_not_contained
# Out:
# ['1Doc3',
#  'Agrapp',
#  'Arukay',
#  'Ayenda',
#  'Bold',
#  'Celucambio',
#  'Datatraffic',
#  'Datup',
#  'Direktio',
#  'Emobi',
#  'Enjoyflowers',
#  'EnLaU',
#  'Enterapia',
#  'Erco Energy',
#  'Escappy travel',
#  'Factcil ',
#  'Foodology',
#  'Fracttal',
#  'Guineo',
#  'HackU',
#  'Helenas',
#  'Hogaru',
#  'Hoy Trabajas',
#  'IMEX',
#  'IMIX',
#  'Kapua',
#  'Kiwi',
#  'LaManicurista',
#  'Life desing ',
#  'Loro',
#  'Medicapp',
#  'Mensajeros Urbanos',
#  'Merqueo',
#  'Mesfix',
#  'Mobijob',
#  'Movii',
#  'Mowies',
#  'Muncher',
#  'Muni ',
#  'MUY',
#  'Packen',
#  'PeakU',
#  'Pencil ',
#  'Pet Valet',
#  'Pinbus',
#  'Platzi',
#  'PlayVox',
#  'Pulzo',
#  'Quqo',
#  'Sense box',
#  'Slang',
#  'Superfuds ',
#  'Symplifica',
#  'Talentu',
#  'Tekus',
#  'Tiendapp',
#  'Torre',
#  'TPaga',
#  'Treble',
#  'Tributi',
#  'TusDatos',
#  'Ubits',
#  'Vecindario',
#  'Vozy',
#  'Vueltap',
#  'Whale and jaguar']

# %% [markdown]
# ### Adicionar campo isInTop100 en el dataframe  df_colombia_company

# %%
df_colombia_company["isInTop100"] = 0

pass
# Out:
# <ipython-input-10-e063b199bc96>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_colombia_company["isInTop100"] = 0

# %%
for company_name in startup_contained:
    df_colombia_company.loc[df_colombia_company['Organization Name'] == company_name, ['isInTop100']] = 1
# Out:
# C:\Users\Administrador\anaconda3\lib\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)

# %%
df_colombia_company
# Out:
#      Organization Name                              Organization Name URL  \
# 0              La Haus    https://www.crunchbase.com/organization/la-haus
# 1               Elenas     https://www.crunchbase.com/organization/elenas
# 2                Dondo  https://www.crunchbase.com/organization/crowdswap
# 3               Aflore     https://www.crunchbase.com/organization/aflore
# 4          Backstartup  https://www.crunchbase.com/organization/backst...
# ..                 ...                                                ...
# 224       Milmenus.com  https://www.crunchbase.com/organization/milmen...
# 225  Market Over Video  https://www.crunchbase.com/organization/market...
# 226             Toomga     https://www.crunchbase.com/organization/toomga
# 227     Deitek Systems  https://www.crunchbase.com/organization/deitek...
# 228        LatinMedios  https://www.crunchbase.com/organization/lgl-la...
#
#                                             Industries  \
# ...

# %%
df_colombia_company.to_csv('.\\resources\\ColombiaFla.csv')
